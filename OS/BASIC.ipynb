# %% [markdown]
# ### Operating system
# An Operating System is system software that acts as an interface between the user and computer hardware.
# It manages all hardware and software resources of a computer.
#
# An Operating System is a program that controls the execution of application programs and acts as an interface between the user and computer hardware.”

# %%
import os

# %%
os.getcwd() # current workind directory
# Out:
# 'c:\\Users\\dell\\Desktop\\Data science\\OS'

# %%
path = r"c:\\Users\\dell\\Desktop\\Data science\\OS"
os.listdir(path)  ## r is raw string
                  ## listdir is used to list of directory
# Out:
# ['BASIC.ipynb']

# %%
os.listdir(r"c:\\Users\\dell\\Desktop\\Data science\\OS")
# Out:
# ['BASIC.ipynb']

# %%
path = r"C:\Users\dell\Desktop\Data science\OS"
os.listdir(path)
# Out:
# ['BASIC.ipynb']

# %%
os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\dell\\Desktop\\Data science\\OS'

# %%
os.makedirs("student\\data\\reports")

# %%
os.listdir(os.getcwd())
# Out:
# ['BASIC.ipynb', 'hello', 'student']

# %%
os.rmdir("hello") # used to remove the folder

# %%
os.listdir(os.getcwd())
# Out:
# ['BASIC.ipynb', 'student']

# %%
os.rename("student","person")   # rename is used to change the name of the folder

# %%
os.listdir(os.getcwd())
# Out:
# ['BASIC.ipynb', 'person']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\dell\\Desktop\\Data science\\OS'

# %%
os.chdir(r"C:\Users\dell\Desktop\Data science\python")  # chdir is used to change the dicrectory

# %%
os.listdir(os.getcwd())
# Out:
# ['assignment.ipynb',
#  'assignment2.ipynb',
#  'basic.py',
#  'classses.ipynb',
#  'condition.ipynb',
#  'constructor.ipynb',
#  'dict.py',
#  'Encapsulation,.ipynb',
#  'function.ipynb',
#  'hello',
#  'inheritance.ipynb',
#  'list.py',
#  'looping.ipynb',
#  'pratice.py',
#  'set.py',
#  'string datatype.py',
#  'student',
#  'tuple.py']

# %%
path = "C:\Program Files\Microsoft Office"
path1 = r"C:\Program Files"
path2 = r"Microsoft Office"
complete_path = os.path.join(path1,path2)  # join is used to join the path
print(complete_path)
print("final output:-",os.listdir(complete_path))
# Out:
# C:\Program Files\Microsoft Office
# final output:- ['Updates']

# %%
os.path.isfile(r"C:\Users\dell\Desktop\Data science\OS\BASIC.ipynb") 
 ## isfile  is used  check the file
# Out:
# True

# %%
os.path.isdir("C:\Users\dell\Desktop\Data science\OS\BASIC.ipynb")
## isdir is used to check directory
# Out:
# True

# %%
os.path.exists(r"C:\Users\dell\Desktop\Data science\OS\BASIC.ipynb")
# Out:
# True

# %%
os.path.getsize(r"C:\Users\dell\Desktop\Data science\OS\BASIC.ipynb")
## is used to show the size of the file
# Out:
# 10434

# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |
