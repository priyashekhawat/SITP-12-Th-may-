# %% [markdown]
# # Class
# A **class** is a blueprint or template used to create objects.
# It contains variables (data) and functions (methods).
#
# **Classes are used in Object-Oriented Programming (OOP).**
#
# A class is a user-defined data type that groups data members and member functions into a single unit.
#
# The four main pillars of OOP used in Python classes are:
#
# Encapsulation
# Abstraction
# Inheritance
# Polymorphism
#
# 1. **Encapsulation**
#
# Encapsulation means wrapping data and methods into a single unit (class).
#
# It helps in data hiding and security
#
# class Student:
#     def __init__(self):
#         self.name = "Rahul"
#
# s = Student()
# print(s.name)
#
# 2. **Abstraction**
#
# Abstraction means hiding unnecessary details and showing only important features.
#
# Example
#
# When we drive a car, we use the steering and brakes without knowing the internal engine details.
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
# 3. **Inheritance**
#
# Inheritance allows one class to acquire properties and methods of another class.
#
# Example
# class Parent:
#     def show(self):
#         print("Parent Class")
#
# class Child(Parent):
#     pass
#
# c = Child()
# c.show()
# Output
# Parent Class
#
#
# 4. **Polymorphism**
#
# Polymorphism means one function can perform many tasks.
# Example
# class Bird:
#     def sound(self):
#         print("Bird sound")
#
# class Dog:
#     def sound(self):
#         print("Dog sound")
#
# b = Bird()
# d = Dog()
#
# b.sound()
# d.sound()
# Output
# Bird sound
# Dog sound

# %% [markdown]
# |Pillar| Defination|Example|
# -------------|------------------------------------------|----------------------|
# Encapsulation| Wrapping data and mrthods into one unit| class and object|
# Inheritance|One class acquires properties of another class| parent--child class|
# Polymorphism| same function behaves differently in different situation|method overriding
# Abstraction|hiding internal details and showing only important features|abstract calss
#
#
#
#
#
# #### OBJECTS
# | Topic                 | Description                                                        |
# | --------------------- | ------------------------------------------------------------------ |
# | **Class**             | A class is a blueprint used to create objects.                     |
# | **Object**            | An object is an instance of a class.                               |
# | **OOP**               | OOP stands for Object-Oriented Programming.                        |
# | **Syntax**            | `class ClassName:`                                                 |
# | **Constructor**       | `__init__()` is a special method used to initialize object values. |
# | **self Keyword**      | `self` refers to the current object of the class.                  |
# | **Method**            | A function inside a class is called a method.                      |
# | **Attribute**         | Variables inside a class are called attributes.                    |
# | **Instance Variable** | Variables created using `self` are instance variables.             |
# | **Object Creation**   | `obj = ClassName()`                                                |
# | **Advantages**        | Code reusability, better structure, easy maintenance.              |

# %%
class Classname: # class is created by class name
    pass

# %%
class Student:
    pass  # class keyword and student name

# %%
class LastName:  
    pass 
# from fastapi import FastAPI

# %%
class Student:
    name = "Priya"  # class variable
    pass

# %%
class Student:
    name = "priya"
st = Student()  ## st is object

# Student - class
# st - object
# name - attribute (class variable)

# %%
class Student:
    name = "priya"
    classes = "second year"
    branch = "CSE"
    roll_no = "24eyuion089"
st = Student()

# %%
st.branch
# Out:
# 'CSE'

# %%
st.name  # it work line by line and remove previous so for show output we can write print
st.branch
st.roll_no
# Out:
# '24eyuion089'

# %%
print(st.name)  # it work line by line and remove previous so for show output we can write print
print(st.branch)
print(st.roll_no)
# Out:
# priya
# CSE
# 24eyuion089

# %%
class College:  # one class can access mulitple objects
    college_name = "SBI"
    college_Address = "siker"
    college_sp = 29

priya = College()  # all this object also access this class
garima = College()
swati = College()

# %%
priya.college_name
# Out:
# 'SBI'

# %%
garima.college_Address
# Out:
# 'siker'

# %%
class College:
    college_name = "SGI IN SIKER"
    def display(a):  #  for method in class you have to pass an argument in it.
        pass


clg = College()

# %%
clg.display() #in class method if you not pass an argument show error

# %%
class College :
    college_name = "SGI"
    college_address = "siker"
    collegesp = 46  # ek class se method ke ander properties inherit karne ke liye self is used
    def show(self):
        print(self.college_name)
        print(self.college_address)
        print(self.collegesp)

class student(College):
    student_name = "priya"
    student_rollnumber = 39
    student_number = 89046768
    student_branch = "cse"
st = student()
st.show()
print(st.student_branch)
# Out:
# SBI MAIN CAMPUS
# siker
# 29
