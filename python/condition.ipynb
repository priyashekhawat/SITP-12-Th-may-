# %%
print("hii  kaise ho ")
# Out:
# hii  kaise ho

# %%
2+6
# Out:
# 8

# %% [markdown]
# ## Condition statement
# **Conditional statement** in programming is a statement that checks a condition and performs different actions based on whether the condition is True or False.

# %% [markdown]
# <span style="color:red"> Types of condition statement in python</span>
# * if statement
#
# * if-else-statement
#
# * if-elif-statement
#
# * nested if statement

# %%
num = input("enter your number")
print(type(num))
# Out:
# <class 'str'>

# %%
num = int(input("enter your number"))
print(type(num))
# Out:
# <class 'int'>

# %%
bal = 8000
# withdraw = int(input("enter your amount")) # for input can take from user.
withdraw = 30000

if withdraw <= bal:
 print("aapke ke account m etne paise hai")

else :
  print("itne paise nhi hai apke account m")
# Out:
# itne paise nhi hai apke account m

# %%
### student fail & pass
max = 35
if max <= 30:
 print("fail")
else :
  print("pass")
# Out:
# pass

# %%
signal = "red"
if signal == "red":
   print("stop")
elif signal == "yellow":
 print("ready")
else:
  print("go")
# Out:
# stop

# %%
#voting system
age = int(input("enter your age")) 
print(age)
if age <= 18 :
 print(" not able to vote")
else:
 print(" able to vote")
# Out:
# 20
#  able to vote

# %%
# blinkit free delivery
amount = int(input("enter your amount"))
print(amount)
if amount <= 500 : # agar if run hogya tho elif or else run nhi hoga 
 print("not get free delivery")
else:
 print("you get free delivery")
# Out:
# 400
# not get free delivery

# %%
# grading system
grade = int(input("enter your number:"))
print(grade)
if grade <= 100  and grade >= 90:
 print("A++")
elif grade <= 90 and grade >= 80:
  print("A")
elif grade <= 80 and grade >= 70:
 print("B")
elif grade <=70 and grade >= 60:
 print("c")
elif grade <=60 and grade >= 50:
 print("D")
elif grade <=50 and grade >= 36:
   print("E")
else:
 print("F")
# Out:
# 45
# E

# %%
# if condition:
#     if condition:
#         #code
#     else:
#         #code
# else:
#     ##code

# %%
attendance = 75
marks = 88
if attendance >= 75:
    if marks >= 36:
        print("pass")
    else:
        print("fail in exam")
else:
    print("low attendance")
# Out:
# pass

# %%
pin = int(input("enter your pin"))
pin1 = int(8642)
amount = int(input("enter withdraw amount"))
print("withdrawal amount:-",amount)
Balance = 80000
print("your Balance:-",Balance)
if pin == pin1 :
    if Balance >= amount :
        print("your transaction is successful")
    else :
        print("not sufficent balcance")
else :
    print("pin is not correct")
# Out:
# withdrawal amount:- 7000
# your Balance:- 80000
# pin is not correct
