# %% [markdown]
# ### Constructor
# A constructor is a special member function of a class that initializes objects automatically when they are created.
#
#
# #### Characteristics of Constructor
# |Feature	|Description|
# |----------------------|-------------------------------------|
# |Same Name as Class|	Constructor name must be same as class name|
# |No Return Type|	Not even void|
# |Automatically Called|	Runs when object is created|
# |Used for Initialization	|Assigns initial values|
# |Can Be Overloaded|	Multiple constructors possible|

# %%
print("constructor")
# Out:
# constructor

# %%
class college:
    def __init__(self):  # this is the syntax of the constructor
        pass
clg = college()

# %%
class college:
    def __init__(self): 
        college_name = "sgi"   # have to write self
clg = college()

# %%
class college:
    def __init__(self):
        self.college_name = "sgi"  ## instance variable
        self.college_address = "siker"
        self.college_sp = "45"

clg = college()
clg.college_name
# Out:
# 'sgi'

# %%
class Student:
    def __init__(self,name,branch,roll_number,classes):
        self.name = name
        self.branch = branch
        self.roll_number = roll_number
        self.classes = classes
    def display(self):
        pass
st = Student(name="priya",branch="cse",roll_number="29",classes= "2ndyear")

# %%
st.name
# Out:
# 'priya'

# %%
st.roll_number
# Out:
# '29'

# %%
data = Student(name="priya",branch="cse",roll_number="29",classes= "2ndyear")
## object is initialized

# %%
data.name
# Out:
# 'priya'

# %%
## mutilevel inheritance using constructer
class student:
    def __init__(self,name,age,course):
        self.name = name
        self.age = age
        self.course = course
class teacher(student):
    def __init__(self,name,age,course,address):
        super().__init__(self,name,age, course)
        super_address = address

class hod:
    def __init__(self,name,age,course,address,department):
        super(). __init__(self,name,age,course,address)
        self.department = department
    def display(self):
        print(" name:-",self.name)
        print("age:-",self.age)
        print("course:_",self.course)
        print("address:-",self.address)
        print("department:-",self.department)
hd = hod(name = "priya", age = 19, address = "siker",course = "")
hd.display()
