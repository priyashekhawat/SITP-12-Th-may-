# %% [markdown]
# ### ATM  System

# %%
class BankAccount:
    def __init__(self):
          self.a = int(input("Enter withdrawal money:-"))
          self.b = int(input("Enter your deposit money"))
          self.bal = 3000
    def deposit_money(self):
        print("The diposited money is:-",self.b)
    def withdraw_money(self):
        print("The withdrawal money is:-",self.a)
    def balance_check(self):
        if self.a>0:
            if self.b > 0:
                self.bal = self.bal + self.b - self.a
            else:
                self.bal = self.bal - self.a
        else:
            self.bal = self.bal + self.b
        print("Your balance is:-",self.bal)
ba = BankAccount()
ba.balance_check()
ba.withdraw_money()
ba.deposit_money()






















# OUTPUT:-
# Out:
# Your balance is:- 3800
# The withdrawal money is:- 600
# The diposited money is:- 1400

# %% [markdown]
# #### BMI (Body mass index)

# %%
# BMI US units
class BMI:
    def __init__(self):
      self.w =float(input("enter your weight in pound :-"))
      self.h =float(input("enter your height in feet :-"))
      self.A = "a"
    def checkbmi(self):
        # to convert weight of pound in kgs by dividing with 2.205
        self.w = self.w/2.205
        
        print(f"Your weight is:- {self.w} in kgs")
        # to convert height of feet in meter by dividing with 3.281
        self.h = self.h/3.281
        print(f"Your height:- {self.h} in Meter")
        self.A = self.w/ self.h **2
        print(f"BMI :-{self.A} kg/m^2")
    
    def checkhealth(self):
       if self.A < 16:
          print("Serve Thinness")  
       elif 16 < self.A < 17:
          print("Moderate Thinness") 
       elif  17 < self.A < 18.5:
          print("Mild Thinness")
       elif  18.5 < self.A < 25:
          print("Normal")
       elif  25 < self.A < 30:
          print("Overweight")
       elif 30 < self.bmi < 35:
          print("Obese Class I")
       elif  35 < self.A < 40:
          print("Obese Class II") 
       else:
          print("Obese Class III")   
b = BMI()
b.checkbmi()
b.checkhealth()






# OUTPUT:-
# Out:
# Your weight is:- 70.74829931972789 in kgs
# Your height:- 1.6458396830234685 in Meter
# BMI :-26.11806183104243 kg/m^2
# Overweight

# %%
# BMI Metric unit
class BMI:
    def __init__(self):
      self.w =float(input("enter your weight in kgs :-"))
      self.h =float(input("enter your height in cms :-"))
      self.A = "a"
    def checkbmi(self):
        print(f"Your weight is:- {self.w} in kgs")
        self.h = self.h/100
        print(f"Your height:- {self.h} in Meter")
        # to convert height of cms into meter by divide cm by 100
        self.A = self.w/ self.h **2
        print(f"BMI :-{self.A} kg/m^2")
    def checkhealth(self):
       if self.A < 16:
          print("Serve Thinness")  
       elif 16 < self.A < 17:
          print("Moderate Thinness") 
       elif  17 < self.A < 18.5:
          print("Mild Thinness")
       elif  18.5 < self.A < 25:
          print("Normal")
       elif  25 < self.A < 30:
          print("Overweight")
       elif 30 < self.A < 35:
          print("Obese Class I")
       elif  35 < self.A < 40:
          print("Obese Class II") 
       else:
          print("Obese Class III")   
b = BMI()
b.checkbmi()
b.checkhealth()
    
# OUTPUT:-
# Out:
# Your weight is:- 55.0 in kgs
# Your height:- 1.58 in Meter
# BMI :-22.031725684986377 kg/m^2
# Normal
